# %%
import os

def print_tree(start_path, prefix=""):
    files = os.listdir(start_path)
    for index, file in enumerate(files):
        path = os.path.join(start_path, file)
        connector = "└── " if index == len(files)-1 else "├── "
        print(prefix + connector + file)
        if os.path.isdir(path):
            extension = "    " if index == len(files)-1 else "│   "
            print_tree(path, prefix + extension)

print_tree(".")
# Out:
# ├── .git
# │   ├── COMMIT_EDITMSG
# │   ├── config
# │   ├── description
# │   ├── FETCH_HEAD
# │   ├── HEAD
# │   ├── hooks
# │   │   ├── applypatch-msg.sample
# │   │   ├── commit-msg.sample
# │   │   ├── fsmonitor-watchman.sample
# │   │   ├── post-checkout
# │   │   ├── post-commit
# │   │   ├── post-merge
# │   │   ├── post-update.sample
# │   │   ├── pre-applypatch.sample
# │   │   ├── pre-commit.sample
# │   │   ├── pre-merge-commit.sample
# │   │   ├── pre-push
# │   │   ├── pre-push.sample
# │   │   ├── pre-rebase.sample
# │   │   ├── pre-receive.sample
# │   │   ├── prepare-commit-msg.sample
# │   │   ├── push-to-checkout.sample
# │   │   ├── sendemail-validate.sample
# │   │   └── update.sample
# │   ├── index
# │   ├── info
# │   │   └── exclude
# │   ├── lfs
# │   │   ├── cache
# │   │   │   └── locks
# │   │   │       └── refs
# │   │   │           └── heads
# │   │   │               └── fb_branch
# │   │   │                   └── verifiable
# │   │   ├── objects
# │   │   │   └── 3b
# │   │   │       └── e1
# │   │   │           └── 3be1d80e1743d43524e368946f13dca78abf22122ba320abdb7b35a206e29ed2
# │   │   └── tmp
# │   ├── logs
# │   │   ├── HEAD
# │   │   └── refs
# │   │       ├── heads
# │   │       │   ├── fb_branch
# │   │       │   └── main
# │   │       └── remotes
# │   │           └── origin
# │   │               ├── fb_branch
# │   │               └── HEAD
# │   ├── objects
# │   │   ├── 10
# │   │   │   └── e8c47d519c142318d436896cbdcf68c10044c0
# │   │   ├── 18
# │   │   │   └── 6e195d527c2d76b94530d152eb217b7f792491
# │   │   ├── 29
# │   │   │   └── e8ddbcb1ff3a9e4365957015a7a15836a8c88c
# │   │   ├── 33
# │   │   │   └── afed2523e8a1e48d4eb8d73b11ed8e30e53c6f
# │   │   ├── 43
# │   │   │   └── b532ace6476d01c6f7911c5549c9ff882dd519
# │   │   ├── 49
# │   │   │   └── b208debc5145f00e92e7dfb1f46f06a9c15d33
# │   │   ├── 4a
# │   │   │   └── 6b2ae665b8beb4f7150e83acdf0d7c6006f0f6
# │   │   ├── 55
# │   │   │   ├── 5226b1fe7e649c304485f67aaa9cdf687f998b
# │   │   │   └── 8b4daa510382f421614c8dd9a9eb495fd65d6e
# │   │   ├── 5b
# │   │   │   └── 6eaca144d3428c92e418cbf95605b89512da20
# │   │   ├── 64
# │   │   │   └── 6a80703351ebe2f4fbdb50769ed679bccd0cf7
# │   │   ├── 76
# │   │   │   └── 95298f4bbafd27ea46883a654d80a6ef9ce1e4
# │   │   ├── 77
# │   │   │   └── f96273af4f0fde5046b19c9b5ffe520be2f664
# │   │   ├── 7d
# │   │   │   └── 528cf4129e7645553b146e367ac55ca643e33b
# │   │   ├── 7f
# │   │   │   └── 85697218d0dd0e8a8c15562e2bc30ba083abb0
# │   │   ├── 88
# │   │   │   └── dfda6722fdf3a1112d3b230095b60710dc24ad
# │   │   ├── 89
# │   │   │   └── 8ea19417a14b5e07bc0328ef0fc7313be14fdb
# │   │   ├── 8b
# │   │   │   └── 137891791fe96927ad78e64b0aad7bded08bdc
# │   │   ├── 9d
# │   │   │   └── 0878d6cce62f5d38086f52ab9810488b0d7dcd
# │   │   ├── a1
# │   │   │   └── fc31e18a59a0f7353c785e29e14f64c9a3d602
# │   │   ├── a5
# │   │   │   └── f9f3635814cfca6497371245dd7207b0fe148b
# │   │   ├── ae
# │   │   │   └── 417ccb312d8fa9a2a3b9aea3b6a8a762bea1ca
# │   │   ├── c0
# │   │   │   └── 9cb27419fe34fc8ae1b6fde3d223735beeed9d
# │   │   ├── c6
# │   │   │   └── d3ced6dcff6785ee19c53473c6cb9b88f5cba9
# │   │   ├── d0
# │   │   │   └── 5aa7cfb72cebfdd68eebc579951894790d7838
# │   │   ├── e1
# │   │   │   └── bf1a441a513424c10e7b78c928f25c5c060986
# │   │   ├── e6
# │   │   │   └── 9de29bb2d1d6434b8b29ae775ad8c2e48c5391
# │   │   ├── ef
# │   │   │   └── 05c3f11a2d8b537621654e754408f79f1252d0
# │   │   ├── f3
# │   │   │   └── 323590bd1464cd6a3f4ab66746a5f071983492
# │   │   ├── info
# │   │   └── pack
# │   │       ├── pack-d06808a3ba21cf494fe893757a23b239de861bdc.idx
# │   │       ├── pack-d06808a3ba21cf494fe893757a23b239de861bdc.pack
# │   │       └── pack-d06808a3ba21cf494fe893757a23b239de861bdc.rev
# │   ├── ORIG_HEAD
# │   ├── packed-refs
# │   └── refs
# │       ├── heads
# │       │   ├── fb_branch
# │       │   └── main
# │       ├── remotes
# │       │   └── origin
# │       │       ├── fb_branch
# │       │       └── HEAD
# │       └── tags
# ├── .gitattributes
# ├── all_files.txt
# ├── all_files_sorted.txt
# ├── data
# │   └── row.csv
# ├── model
# │   └── ml_model.pkl
# ├── model.ml_model.pkl
# ├── notebooks
# │   ├── classic_ml.ipynb
# │   ├── eda.ipynb
# │   ├── GRU.ipynb
# │   └── Transformer.ipynb
# ├── Print_Repo.ipynb
# ├── README.md
# ├── src
# │   ├── models
# │   │   ├── classical_ml.py
# │   │   ├── GRU.py
# │   │   ├── preprocessing.py
# │   │   ├── transformer.py
# │   │   └── __pycache__
# │   │       ├── classical_ml.cpython-310.pyc
# │   │       └── preprocessing.cpython-310.pyc
# │   ├── __init__.py
# │   └── __pycache__
# │       └── __init__.cpython-310.pyc
# └── streamlit_app
#     └── app.py
